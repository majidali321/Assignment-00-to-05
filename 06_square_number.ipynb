# %% [markdown]
# <a href="https://colab.research.google.com/github/majidali321/Assignment-00-to-05/blob/main/06_square_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def main():
    num: float = float(input("Type a number to see its square: "))
    print(str(num) + " squared is " + str(num ** 2))


# There is no need to edit code beyond this point

if __name__ == '__main__':
    main()
# Out:
# Type a number to see its square: 66
# 66.0 squared is 4356.0
