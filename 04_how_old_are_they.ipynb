# %% [markdown]
# <a href="https://colab.research.google.com/github/majidali321/Assignment-00-to-05/blob/main/04_how_old_are_they.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def main():
    anton : int = 21
    beth : int = 6 + anton
    chen : int = 20 + beth
    drew  : int= chen + anton
    ethan : int = chen

    print("Anton is " + str(anton))
    print("Beth is " + str(beth))
    print("Chen is " + str(chen))
    print("Drew is " + str(drew))
    print("Ethan is " + str(ethan))



if __name__ == '__main__':
    main()
# Out:
# Anton is 21
# Beth is 27
# Chen is 47
# Drew is 68
# Ethan is 47
