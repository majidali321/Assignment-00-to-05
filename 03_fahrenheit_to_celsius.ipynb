# %% [markdown]
# <a href="https://colab.research.google.com/github/majidali321/Assignment-00-to-05/blob/main/03_fahrenheit_to_celsius.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def main():
    degrees_fahrenheit = float(input("Enter temperature in Fahrenheit: "))
    degrees_celsius = (degrees_fahrenheit - 32) * 5.0 / 9.0
    print(f"Temperature is {degrees_celsius:.15f}°C")

if __name__ == "__main__":
    main()
# Out:
# Enter temperature in Fahrenheit: 55
# Temperature is 12.777777777777779°C
