# %% [markdown]
# <a href="https://colab.research.google.com/github/majidali321/Assignment-00-to-05/blob/main/02_agreement_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def main():
  print("what is your faviourite animal?")
  animal = input()
  print(f"My faviourite animal is also {animal}")

if __name__ == "__main__":
  main()
# Out:
# what is your faviourite animal?
# bhaloo
# My faviourite animal is bhaloo
